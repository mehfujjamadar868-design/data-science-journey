# %% [markdown]
# <a href="https://colab.research.google.com/github/mehfujjamadar868-design/data-science-journey/blob/main/Day_2_Comparison_Operators_and_Conditionals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
score = 85

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
else:

    print("Grade: C")
# Out:
# Grade: B

# %%
is_weekend = True
has_free_time = False

if is_weekend and has_free_time:
    print("Time for a 2-hour deep dive!")
elif is_weekend or has_free_time:
    print("Let's write down some quick notes.")
else:
    print("Back to the busy weekday schedule!")
# Out:
# Let's write down some quick notes.

# %%
#'''in the  Comparison operators , control flow , logical operators ,we use to add conditons'''
