# %% [markdown]
# <a href="https://colab.research.google.com/github/mehfujjamadar868-design/data-science-journey/blob/main/day_01_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Data Science!")

# %%
# Data Science + Machine Learning Journey
# Day 01 - Setup

print("Hello, Data Science!")
print("My Data Science journey has started.")
# Out:
# Hello, Data Science!
# My Data Science journey has started.
