# %% [markdown]
# <a href="https://colab.research.google.com/github/mehfujjamadar868-design/data-science-journey/blob/main/DAY_1_variable_and_data_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
topic = "Data Science"
days_completed = 0
is_excited = True

# %%
print(topic, type(topic))
print(days_completed, type(days_completed))
print(is_excited, type(is_excited))
# Out:
# Data Science <class 'str'>
# 0 <class 'int'>
# True <class 'bool'>

# %%
days_completed = int(1)
target_days = int(120)
target_days-days_completed
# Out:
# 119

# %%
result_1 = 10 / 3
result_2 = 10 // 3

print("Result 1:", result_1, type(result_1))
print("Result 2:", result_2, type(result_2))
# Out:
# Result 1: 3.3333333333333335 <class 'float'>
# Result 2: 3 <class 'int'>
