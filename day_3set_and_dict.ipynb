# %% [markdown]
# <a href="https://colab.research.google.com/github/mehfujjamadar868-design/data-science-journey/blob/main/day_3set_and_dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
categories = ("Electronics", "Clothing", "Electronics", "Home", "Clothing")
categories = set(categories)
print(type(categories))
print(categories)
# Out:
# <class 'set'>
# {'Home', 'Clothing', 'Electronics'}

# %%
categories = {"Electronics", "Clothing", "Electronics", "Home", "Clothing"}
type(categories)
#print(categories)
# Out:
# set

# %%
score = [0.82,0.88,0.85]
score.append(0.93)
print(score)
print(max(score))
# Out:
# [0.82, 0.88, 0.85, 0.93]
# 0.93

# %%
model_info ={
'name': "XGBoost",
'accuracy': 0.94,
'status': "Deployed"
}
print(f"Model {model_info['name']} is {model_info["accuracy"]}.")
# Out:
# Model XGBoost is 0.94.
